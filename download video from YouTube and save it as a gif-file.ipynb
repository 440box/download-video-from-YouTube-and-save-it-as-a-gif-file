# %% [markdown]
# # 1.Install software

# %%
# !pip install --upgrade yt_dlp
# !apt -y install ffmpeg lame
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 43.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.6 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# Suggested packages:
#   lame-doc
# The following NEW packages will be installed:
#   lame
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 51.3 kB of archives.
# After this operation, 129 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lame amd64 3.100-3build2 [51.3 kB]
# Fetched 51.3 kB in 0s (345 kB/s)
# ...

# %% [markdown]
# # a. Change the URLs which one you want to download from youtube yt_urls = ['put it there']

# %%
# Change the URLs which one you want to download from youtube
yt_urls = ['https://www.youtube.com/watch?v=Q2cUGICVEhI']

# change this to /content/
output_folder = '/content/'

import os
def my_mkdirs(folder):
  if os.path.exists(folder)==False:
    os.makedirs(folder)
my_mkdirs('/content/tmp/')

my_mkdirs(output_folder)

# %%
# download youtube videos and save it co /content/tmp
for ind,url in enumerate(yt_urls):
  # !yt-dlp --restrict-filenames --trim-filenames 25 $url -o input.webm
## for username, password and twofactor use options
# -u, --username USERNAME
#       Login with this account ID
# -p, --password PASSWORD
#       Account password. If this option is left out, yt-dlp will ask interactively
# -2, --twofactor TWOFACTOR
#       Two-factor authentication code
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Q2cUGICVEhI
# [youtube] Q2cUGICVEhI: Downloading webpage
# [youtube] Q2cUGICVEhI: Downloading ios player API JSON
# [youtube] Q2cUGICVEhI: Downloading android player API JSON
# [youtube] Q2cUGICVEhI: Downloading m3u8 information
# [info] Q2cUGICVEhI: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 31
# [download] Destination: input.f616.mp4
# [download] 100% of   22.86MiB in 00:00:02 at 10.65MiB/s
# [download] Destination: input.f251.webm
# [download] 100% of    1.63MiB in 00:00:00 at 17.03MiB/s
# [Merger] Merging formats into "input.webm"
# Deleting original file input.f616.mp4 (pass -k to keep)
# Deleting original file input.f251.webm (pass -k to keep)

# %% [markdown]
# than execute next step
# to get a GIF file

# %%
# !ffmpeg -i input.webm -vf "fps=10,scale=320:-1:flags=lanczos" -c:v gif output.gif
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# check and click to folder icon on the left side, than you can see explorer like interface and final target output.gif .
# Click on three dots and choose "download"
